# %% [markdown]
# # Implementing K-Means Clustering
# The k-means algorithm searches for a pre-determined number of clusters within an unlabeled multidimensional dataset. It accomplishes this using a simple conception of what the optimal clustering looks like:
#
# The "cluster center" is the arithmetic mean of all the points belonging to the cluster.
#
# Each point is closer to its own cluster center than to other cluster centers.
#
# Here in this code we will be implementing K-Means Clustering on a manually generated dataset and a online available realtime
# dataset

# %%
#importing libraries for number manipulation dataframe operation and graphs

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %% [markdown]
# Here we have used sklearn samples generator to create a 2d dataset with 500 members and 3 clusters. This dataset will be
# arragned in such a way that 500 point will form three clusters which we will try to detect using k means algorithm and in last
# line using matplotlib we have drawn graph for those points

# %%
from sklearn.datasets.samples_generator import make_blobs
X, y = make_blobs(n_samples=500, centers=3,cluster_std=0.50, random_state=0)
plt.scatter(X[:, 0], X[:, 1], s=50);

# %% [markdown]
# Here we have imported KMeans from sklearn.clusters the created its object with 3 number of cluster then fit that on X that we have generated above and made predictions now y_kmeans contains 3 label denoting each point that to what cluster it belongs

# %%
from sklearn.cluster import KMeans
kmeans_cls = KMeans(n_clusters=3)
kmeans_cls.fit(X)
y_kmeans = kmeans_cls.predict(X)

# %% [markdown]
# Now we plotted the predicted clusters and centeroid of each cluster is also shown by black dot

# %%
plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, s=50, cmap='viridis')

centers = kmeans_cls.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %% [markdown]
# Importing dataset using pandas

# %%
dataset = pd.read_csv('clustering.csv' , encoding='cp437')

# %% [markdown]
# lets have look at dataset using head() function it will show first 5 rows of dataset

# %%
dataset.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %% [markdown]
# We want to cluster costumers based on annual income and the amount they spend which is denoted by spending score which is between 1 and 100
# That is why we have selected x from 3th to 5th column (5th exclusive [3,5))

# %%
x=dataset.iloc[:,3:5].values

# %% [markdown]
# Lets visualise the data using scatter plot

# %%
plt.scatter(x[:, 0], x[:, 1], s=50);

# %% [markdown]
# Here we have imported KMeans from sklearn.clusters the created its object with 5 number of cluster then fit that on x that we
# have generated above and made predictions now y_kmeans contains 5 label denoting each point that to what cluster it belongs

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5)
kmeans.fit(x)
y_kmeans = kmeans.predict(x)

# %% [markdown]
# Now lets plot the results and see how clusters are formed

# %%
plt.scatter(x[:, 0], x[:, 1], c=y_kmeans, s=50, cmap='viridis')

centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);
plt.title('Clusters of Customers')
plt.xlabel('Annual Income in k$)')
plt.ylabel('Spending Score between 1 and 100')
plt.show()

# %% [markdown]
# # The interpretation of the graph is clear there are 5 segments of costumers
# 1 yellow, costumers in this cluster earns less spends less
#
# 2 black, costumers in this cluster earn less but spend more
#
# 3 parrot green, costumers in this cluster are ideal target costumer as they earn more and spend more
#
# 4 blue, costumers in this cluster they are moderate they earn average spend avergae
#
# 5 sea green, costumers in this cluster earn more and spend less
